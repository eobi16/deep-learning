# %% [markdown]
# <a href="https://colab.research.google.com/github/eobi16/deep-learning/blob/main/Monte_Carlo_Simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy pandas scipy matplotlib plotly yfinance scikit-learn statsmodels

# %%
#Download Historical Market Data
import yfinance as yf

def get_data():

    tickers = ['SPY','QQQ','GLD','TLT','IBIT']

    data = yf.download(
        tickers,
        start='2018-01-01'
    )['Close']

    return data

# %%
prices = get_data()
# Out:
# /tmp/ipykernel_6806/3278275308.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
# [*********************100%***********************]  5 of 5 completed

# %%
#Calculate Daily Returns
import pandas as pd

def calculate_returns(prices):

    returns = prices.pct_change()

    returns = returns.dropna()

    return returns

# %%
#Estimate Statistical Parameters
def estimate_parameters(returns):

    mean_returns = returns.mean()

    covariance = returns.cov()

    volatility = returns.std()

    return mean_returns, covariance, volatility
